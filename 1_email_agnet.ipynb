# %%
from dotenv import load_dotenv
from model import CustomLLM
import os
load_dotenv()
# Out:
# True

# %%
# 从环境变量获取 API 密钥，如果不存在则使用默认值
api_key = os.environ.get("OPENAI_API_KEY", "")
model_name = os.environ.get("OPENAI_MODEL_NAME", "")
endpoint = os.environ.get("OPENAI_ENDPOINT", "")

Myllm = CustomLLM(api_key=api_key, model=model_name, endpoint=endpoint)

# %%
Myllm.call("What is the capital of France?")
# Out:
# "The capital of France is **Paris**. \n\nParis is renowned for its rich history, iconic landmarks such as the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral, as well as its significant cultural influence in art, fashion, and cuisine. Let me know if you'd like more details!"

# %%
from crewai import Agent, Task, Crew

email_assistant = Agent(
    role="Email Agent",
    goal="Improve emails and make them sound professional and clear",
    backstory="A highly experienced communication expert skilled in professional email writing",
    verbose=True,
    llm=Myllm,
)

original_email = """
hey team, just wanted to tell u that demo is kind of ready, but there's still stuff left.
Maybe we can show what we have and say rest is WIP.
Let me know what u think. thanks
"""

email_task = Task(
    description=f"""Take the following rough email and rewrite it into a professional and polished version.
    Expand abbreviations:
    '''{original_email}'''""",
    agent=email_assistant,
    expected_output="A professional written email with proper formatting and content",
)

crew = Crew(
    agents=[email_assistant],
    tasks=[email_task],
    verbose=True,
    )

result = crew.kickoff()
print(result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 445a1d8d-627b-44b8-bb81-84da4294f013                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Email Agent                                                                                             │
# │                                                                                                                 │
# │  Task: Take the following rough email and rewrite it into a professional and polished version.                  │
# │      Expand abbreviations:                                                                                      │
# │      '''                                                                                                        │
# │  hey team, just wanted to tell u that demo is kind of ready, but there's still stuff left.                      │
# │  Maybe we can show what we have and say rest is WIP.                                                            │
# │  Let me know what u think. thanks                                                                               │
# │  '''                                                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Email Agent                                                                                             │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **Subject:** Update on Demo Status and Next Steps                                                              │
# │                                                                                                                 │
# │  Dear Team,                                                                                                     │
# │                                                                                                                 │
# │  I hope this message finds you well. I’d like to provide a quick update on the demo we’ve been working on. The  │
# │  current version is nearly ready, though there are still some remaining tasks to complete.                      │
# │                                                                                                                 │
# │  Would it be beneficial to present the progress we’ve made so far and clarify that certain components are       │
# │  still a work in progress (WIP)? This approach could help gather feedback early while we finalize the           │
# │  outstanding items.                                                                                             │
# │                                                                                                                 │
# │  Please share your thoughts or suggestions at your earliest convenience. Your input would be greatly            │
# │  appreciated.                                                                                                   │
# │                                                                                                                 │
# │  Thank you,                                                                                                     │
# │  [Your Name]                                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 910a7009-b480-43e3-ba3f-8c1c2f9b514e                                                                     │
# │  Agent: Email Agent                                                                                             │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# **Subject:** Update on Demo Status and Next Steps
#
# Dear Team,
#
# I hope this message finds you well. I’d like to provide a quick update on the demo we’ve been working on. The current version is nearly ready, though there are still some remaining tasks to complete.
#
# Would it be beneficial to present the progress we’ve made so far and clarify that certain components are still a work in progress (WIP)? This approach could help gather feedback early while we finalize the outstanding items.
#
# Please share your thoughts or suggestions at your earliest convenience. Your input would be greatly appreciated.
#
# Thank you,
# [Your Name]
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 445a1d8d-627b-44b8-bb81-84da4294f013                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: **Subject:** Update on Demo Status and Next Steps                                                │
# │                                                                                                                 │
# │  Dear Team,                                                                                                     │
# │                                                                                                                 │
# │  I hope this message finds you well. I’d like to provide a quick update on the demo we’ve been working on. The  │
# │  current version is nearly ready, though there are still some remaining tasks to complete.                      │
# │                                                                                                                 │
# │  Would it be beneficial to present the progress we’ve made so far and clarify that certain components are       │
# │  still a work in progress (WIP)? This approach could help gather feedback early while we finalize the           │
# │  outstanding items.                                                                                             │
# │                                                                                                                 │
# │  Please share your thoughts or suggestions at your earliest convenience. Your input would be greatly            │
# │  appreciated.                                                                                                   │
# │                                                                                                                 │
# │  Thank you,                                                                                                     │
# │  [Your Name]                                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
