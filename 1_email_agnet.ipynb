# %%
from dotenv import load_dotenv
from model import CustomLLM
import os
load_dotenv()

# %%
# 从环境变量获取 API 密钥，如果不存在则使用默认值
api_key = os.environ.get("OPENAI_API_KEY", "")
model_name = os.environ.get("OPENAI_MODEL_NAME", "")
endpoint = os.environ.get("OPENAI_ENDPOINT", "")

Myllm = CustomLLM(api_key=api_key, model=model_name, endpoint=endpoint)

# %%
Myllm.call("What is the capital of France?")

# %%
from crewai import Agent, Task, Crew

# Assuming you have the CustomLLM class defined above
# Create your custom LLM
custom_llm = CustomLLM(
    model=model_name,
    api_key=api_key,
    endpoint=endpoint,
    temperature=0.7
)

# Use with an agent
agent = Agent(
    role="Research Assistant",
    goal="Find and analyze information",
    backstory="You are a research assistant.",
    llm=custom_llm
)

# Create and execute tasks
task = Task(
    description="Research the latest developments in AI",
    expected_output="A comprehensive summary",
    agent=agent
)

crew = Crew(agents=[agent], tasks=[task])
result = crew.kickoff()
# Out:
# An unknown error occurred. Please check the details below.
# Error details: CustomLLM.call() got an unexpected keyword argument 'from_task'
# An unknown error occurred. Please check the details below.
# Error details: CustomLLM.call() got an unexpected keyword argument 'from_task'
# An unknown error occurred. Please check the details below.
# Error details: CustomLLM.call() got an unexpected keyword argument 'from_task'
# An unknown error occurred. Please check the details below.
# Error details: CustomLLM.call() got an unexpected keyword argument 'from_task'
# An unknown error occurred. Please check the details below.
# Error details: CustomLLM.call() got an unexpected keyword argument 'from_task'
# An unknown error occurred. Please check the details below.
# Error details: CustomLLM.call() got an unexpected keyword argument 'from_task'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agent\core.py:389, in Agent.execute_task(self, task, context, tools)
#     388     else:
# --> 389         result = self._execute_without_timeout(task_prompt, task)
#     391 except TimeoutError as e:
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agent\core.py:485, in Agent._execute_without_timeout(self, task_prompt, task)
#     483     raise RuntimeError("Agent executor is not initialized.")
# --> 485 return self.agent_executor.invoke(
#     486     {
#     487         "input": task_prompt,
#     488         "tool_names": self.agent_executor.tools_names,
#     489         "tools": self.agent_executor.tools_description,
#     490         "ask_for_human_input": task.human_input,
#     491     }
#     492 )["output"]
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:192, in CrewAgentExecutor.invoke(self, inputs)
#     191 try:
# --> 192     formatted_answer = self._invoke_loop()
#     193 except AssertionError:
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:303, in CrewAgentExecutor._invoke_loop(self)
#     302     handle_unknown_error(self._printer, e)
# --> 303     raise e
#     304 finally:
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:233, in CrewAgentExecutor._invoke_loop(self)
#     231 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 233 answer = get_llm_response(
#     234     llm=self.llm,
#     235     messages=self.messages,
#     236     callbacks=self.callbacks,
#     237     printer=self._printer,
#     238     from_task=self.task,
#     239     from_agent=self.agent,
#     240     response_model=self.response_model,
#     241     executor_context=self,
#     242 )
#     243 formatted_answer = process_llm_response(answer, self.use_stop_words)  # type: ignore[assignment]
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\utilities\agent_utils.py:276, in get_llm_response(llm, messages, callbacks, printer, from_task, from_agent, response_model, executor_context)
#     275 except Exception as e:
# --> 276     raise e
#     277 if not answer:
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\utilities\agent_utils.py:268, in get_llm_response(llm, messages, callbacks, printer, from_task, from_agent, response_model, executor_context)
#     267 try:
# --> 268     answer = llm.call(
#     269         messages,
#     270         callbacks=callbacks,
#     271         from_task=from_task,
#     272         from_agent=from_agent,  # type: ignore[arg-type]
#     273         response_model=response_model,
#     274     )
#     275 except Exception as e:
#
# TypeError: CustomLLM.call() got an unexpected keyword argument 'from_task'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agent\core.py:389, in Agent.execute_task(self, task, context, tools)
#     388     else:
# --> 389         result = self._execute_without_timeout(task_prompt, task)
#     391 except TimeoutError as e:
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agent\core.py:485, in Agent._execute_without_timeout(self, task_prompt, task)
#     483     raise RuntimeError("Agent executor is not initialized.")
# --> 485 return self.agent_executor.invoke(
#     486     {
#     487         "input": task_prompt,
#     488         "tool_names": self.agent_executor.tools_names,
#     489         "tools": self.agent_executor.tools_description,
#     490         "ask_for_human_input": task.human_input,
#     491     }
#     492 )["output"]
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:192, in CrewAgentExecutor.invoke(self, inputs)
#     191 try:
# --> 192     formatted_answer = self._invoke_loop()
#     193 except AssertionError:
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:303, in CrewAgentExecutor._invoke_loop(self)
#     302     handle_unknown_error(self._printer, e)
# --> 303     raise e
#     304 finally:
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:233, in CrewAgentExecutor._invoke_loop(self)
#     231 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 233 answer = get_llm_response(
#     234     llm=self.llm,
#     235     messages=self.messages,
#     236     callbacks=self.callbacks,
#     237     printer=self._printer,
#     238     from_task=self.task,
#     239     from_agent=self.agent,
#     240     response_model=self.response_model,
#     241     executor_context=self,
#     242 )
#     243 formatted_answer = process_llm_response(answer, self.use_stop_words)  # type: ignore[assignment]
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\utilities\agent_utils.py:276, in get_llm_response(llm, messages, callbacks, printer, from_task, from_agent, response_model, executor_context)
#     275 except Exception as e:
# --> 276     raise e
#     277 if not answer:
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\utilities\agent_utils.py:268, in get_llm_response(llm, messages, callbacks, printer, from_task, from_agent, response_model, executor_context)
#     267 try:
# --> 268     answer = llm.call(
#     269         messages,
#     270         callbacks=callbacks,
#     271         from_task=from_task,
#     272         from_agent=from_agent,  # type: ignore[arg-type]
#     273         response_model=response_model,
#     274     )
#     275 except Exception as e:
#
# TypeError: CustomLLM.call() got an unexpected keyword argument 'from_task'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 28
#      21 task = Task(
#      22     description="Research the latest developments in AI",
#      23     expected_output="A comprehensive summary",
#      24     agent=agent
#      25 )
#      27 crew = Crew(agents=[agent], tasks=[task])
# ---> 28 result = crew.kickoff()
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\crew.py:714, in Crew.kickoff(self, inputs)
#     711 inputs = prepare_kickoff(self, inputs)
#     713 if self.process == Process.sequential:
# --> 714     result = self._run_sequential_process()
#     715 elif self.process == Process.hierarchical:
#     716     result = self._run_hierarchical_process()
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\crew.py:1073, in Crew._run_sequential_process(self)
#    1071 def _run_sequential_process(self) -> CrewOutput:
#    1072     """Executes tasks sequentially and returns the final output."""
# -> 1073     return self._execute_tasks(self.tasks)
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\crew.py:1159, in Crew._execute_tasks(self, tasks, start_index, was_replayed)
#    1156     futures.clear()
#    1158 context = self._get_context(task, task_outputs)
# -> 1159 task_output = task.execute_sync(
#    1160     agent=exec_data.agent,
#    1161     context=context,
#    1162     tools=exec_data.tools,
#    1163 )
#    1164 task_outputs.append(task_output)
#    1165 self._process_task_result(task, task_output)
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\task.py:458, in Task.execute_sync(self, agent, context, tools)
#     451 def execute_sync(
#     452     self,
#     453     agent: BaseAgent | None = None,
#     454     context: str | None = None,
#     455     tools: list[BaseTool] | None = None,
#     456 ) -> TaskOutput:
#     457     """Execute the task synchronously."""
# --> 458     return self._execute_core(agent, context, tools)
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\task.py:695, in Task._execute_core(self, agent, context, tools)
#     693 self.end_time = datetime.datetime.now()
#     694 crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))  # type: ignore[no-untyped-call]
# --> 695 raise e
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\task.py:626, in Task._execute_core(self, agent, context, tools)
#     624 self.processed_by_agents.add(agent.role)
#     625 crewai_event_bus.emit(self, TaskStartedEvent(context=context, task=self))  # type: ignore[no-untyped-call]
# --> 626 result = agent.execute_task(
#     627     task=self,
#     628     context=context,
#     629     tools=tools,
#     630 )
#     632 if not self._guardrails and not self._guardrail:
#     633     pydantic_output, json_output = self._export_output(result)
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agent\core.py:423, in Agent.execute_task(self, task, context, tools)
#     414         crewai_event_bus.emit(
#     415             self,
#     416             event=AgentExecutionErrorEvent(
#    (...)    420             ),
#     421         )
#     422         raise e
# --> 423     result = self.execute_task(task, context, tools)
#     425 if self.max_rpm and self._rpm_controller:
#     426     self._rpm_controller.stop_rpm_counter()
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agent\core.py:423, in Agent.execute_task(self, task, context, tools)
#     414         crewai_event_bus.emit(
#     415             self,
#     416             event=AgentExecutionErrorEvent(
#    (...)    420             ),
#     421         )
#     422         raise e
# --> 423     result = self.execute_task(task, context, tools)
#     425 if self.max_rpm and self._rpm_controller:
#     426     self._rpm_controller.stop_rpm_counter()
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agent\core.py:422, in Agent.execute_task(self, task, context, tools)
#     413     if self._times_executed > self.max_retry_limit:
#     414         crewai_event_bus.emit(
#     415             self,
#     416             event=AgentExecutionErrorEvent(
#    (...)    420             ),
#     421         )
# --> 422         raise e
#     423     result = self.execute_task(task, context, tools)
#     425 if self.max_rpm and self._rpm_controller:
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agent\core.py:389, in Agent.execute_task(self, task, context, tools)
#     385         result = self._execute_with_timeout(
#     386             task_prompt, task, self.max_execution_time
#     387         )
#     388     else:
# --> 389         result = self._execute_without_timeout(task_prompt, task)
#     391 except TimeoutError as e:
#     392     crewai_event_bus.emit(
#     393         self,
#     394         event=AgentExecutionErrorEvent(
#    (...)    398         ),
#     399     )
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agent\core.py:485, in Agent._execute_without_timeout(self, task_prompt, task)
#     482 if not self.agent_executor:
#     483     raise RuntimeError("Agent executor is not initialized.")
# --> 485 return self.agent_executor.invoke(
#     486     {
#     487         "input": task_prompt,
#     488         "tool_names": self.agent_executor.tools_names,
#     489         "tools": self.agent_executor.tools_description,
#     490         "ask_for_human_input": task.human_input,
#     491     }
#     492 )["output"]
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:192, in CrewAgentExecutor.invoke(self, inputs)
#     189 self.ask_for_human_input = bool(inputs.get("ask_for_human_input", False))
#     191 try:
# --> 192     formatted_answer = self._invoke_loop()
#     193 except AssertionError:
#     194     self._printer.print(
#     195         content="Agent failed to reach a final answer. This is likely a bug - please report it.",
#     196         color="red",
#     197     )
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:303, in CrewAgentExecutor._invoke_loop(self)
#     301         continue
#     302     handle_unknown_error(self._printer, e)
# --> 303     raise e
#     304 finally:
#     305     self.iterations += 1
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:233, in CrewAgentExecutor._invoke_loop(self)
#     229     break
#     231 enforce_rpm_limit(self.request_within_rpm_limit)
# --> 233 answer = get_llm_response(
#     234     llm=self.llm,
#     235     messages=self.messages,
#     236     callbacks=self.callbacks,
#     237     printer=self._printer,
#     238     from_task=self.task,
#     239     from_agent=self.agent,
#     240     response_model=self.response_model,
#     241     executor_context=self,
#     242 )
#     243 formatted_answer = process_llm_response(answer, self.use_stop_words)  # type: ignore[assignment]
#     245 if isinstance(formatted_answer, AgentAction):
#     246     # Extract agent fingerprint if available
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\utilities\agent_utils.py:276, in get_llm_response(llm, messages, callbacks, printer, from_task, from_agent, response_model, executor_context)
#     268     answer = llm.call(
#     269         messages,
#     270         callbacks=callbacks,
#    (...)    273         response_model=response_model,
#     274     )
#     275 except Exception as e:
# --> 276     raise e
#     277 if not answer:
#     278     printer.print(
#     279         content="Received None or empty response from LLM call.",
#     280         color="red",
#     281     )
#
# File d:\PythonIDE\jupyter\crewAI\crew-ai\.venv\Lib\site-packages\crewai\utilities\agent_utils.py:268, in get_llm_response(llm, messages, callbacks, printer, from_task, from_agent, response_model, executor_context)
#     265     messages = executor_context.messages
#     267 try:
# --> 268     answer = llm.call(
#     269         messages,
#     270         callbacks=callbacks,
#     271         from_task=from_task,
#     272         from_agent=from_agent,  # type: ignore[arg-type]
#     273         response_model=response_model,
#     274     )
#     275 except Exception as e:
#     276     raise e
#
# TypeError: CustomLLM.call() got an unexpected keyword argument 'from_task'

# %%
from crewai import Agent, Task, Crew

email_assistant = Agent(
    role="Email Agent",
    goal="Improve emails and make them sound professional and clear",
    backstory="A highly experienced communication expert skilled in professional email writing",
    verbose=True,
    llm=Myllm,
)

original_email = """
hey team, just wanted to tell u that demo is kind of ready, but there's still stuff left.
Maybe we can show what we have and say rest is WIP.
Let me know what u think. thanks
"""

email_task = Task(
    description=f"""Take the following rough email and rewrite it into a professional and polished version.
    Expand abbreviations:
    '''{original_email}'''""",
    agent=email_assistant,
    expected_output="A professional written email with proper formatting and content",
)

crew = Crew(
    agents=[email_assistant],
    tasks=[email_task],
    verbose=True,
    )

result = crew.kickoff()
print(result)
