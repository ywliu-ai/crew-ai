# %%
from dotenv import load_dotenv
from model import CustomLLM
import os
load_dotenv()
# Out:
# True

# %%
# 从环境变量获取 API 密钥，如果不存在则使用默认值
api_key = os.environ.get("OPENAI_API_KEY", "")
model_name = os.environ.get("OPENAI_MODEL_NAME", "")
endpoint = os.environ.get("OPENAI_ENDPOINT", "")

Myllm = CustomLLM(api_key=api_key, model=model_name, endpoint=endpoint)

# %%
Myllm.call("What is the capital of France?")
# Out:
# "The capital of France is **Paris**.  \n\nParis is located in the northern part of France and is known for its historical landmarks, such as the **Eiffel Tower**, the **Louvre Museum**, and **Notre-Dame Cathedral**. It is also a global center for art, fashion, cuisine, and culture. \n\nLet me know if you'd like more details! 😊"

# %%
from crewai import Agent, Task, Crew

email_assistant = Agent(
    role="Email Agent",
    goal="Improve emails and make them sound professional and clear",
    backstory="A highly experienced communication expert skilled in professional email writing",
    verbose=True,
    llm=Myllm,
)

original_email = """
hey team, just wanted to tell u that demo is kind of ready, but there's still stuff left.
Maybe we can show what we have and say rest is WIP.
Let me know what u think. thanks
"""

email_task = Task(
    description=f"""Take the following rough email and rewrite it into a professional and polished version.
    Expand abbreviations:
    '''{original_email}'''""",
    agent=email_assistant,
    expected_output="A professional written email with proper formatting and content",
)

crew = Crew(
    agents=[email_assistant],
    tasks=[email_task],
    verbose=True,
    )

result = crew.kickoff()
print(result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: f0cb9b33-8cd3-4302-9e15-ae16951eb025                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Email Agent                                                                                             │
# │                                                                                                                 │
# │  Task: Take the following rough email and rewrite it into a professional and polished version.                  │
# │      Expand abbreviations:                                                                                      │
# │      '''                                                                                                        │
# │  hey team, just wanted to tell u that demo is kind of ready, but there's still stuff left.                      │
# │  Maybe we can show what we have and say rest is WIP.                                                            │
# │  Let me know what u think. thanks                                                                               │
# │  '''                                                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Email Agent                                                                                             │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **Subject:** Update on Project Demo Status                                                                     │
# │                                                                                                                 │
# │  Dear Team,                                                                                                     │
# │                                                                                                                 │
# │  I hope this message finds you well. I wanted to provide you with an update regarding the project demo.         │
# │                                                                                                                 │
# │  The demo is nearing completion, though there are still some outstanding items that require additional work.    │
# │  However, I believe we can proceed with showcasing the current progress and communicate that the remaining      │
# │  components are still in progress (WIP).                                                                        │
# │                                                                                                                 │
# │  Please let me know your thoughts on this approach or if you'd prefer to wait until everything is finalized.    │
# │  Your feedback is greatly appreciated.                                                                          │
# │                                                                                                                 │
# │  Thank you for your time and cooperation.                                                                       │
# │                                                                                                                 │
# │  Best regards,                                                                                                  │
# │  [Your Full Name]                                                                                               │
# │  [Your Position]                                                                                                │
# │  [Your Contact Information]                                                                                     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │  This version adheres to professional standards with clear language, proper formatting, and a courteous tone.   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 33115042-a970-48c2-b8df-14daefed293f                                                                     │
# │  Agent: Email Agent                                                                                             │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# **Subject:** Update on Project Demo Status
#
# Dear Team,
#
# I hope this message finds you well. I wanted to provide you with an update regarding the project demo.
#
# The demo is nearing completion, though there are still some outstanding items that require additional work. However, I believe we can proceed with showcasing the current progress and communicate that the remaining components are still in progress (WIP).
#
# Please let me know your thoughts on this approach or if you'd prefer to wait until everything is finalized. Your feedback is greatly appreciated.
#
# Thank you for your time and cooperation.
#
# Best regards,
# [Your Full Name]
# [Your Position]
# [Your Contact Information]
#
# ---
# This version adheres to professional standards with clear language, proper formatting, and a courteous tone.
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: f0cb9b33-8cd3-4302-9e15-ae16951eb025                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: **Subject:** Update on Project Demo Status                                                       │
# │                                                                                                                 │
# │  Dear Team,                                                                                                     │
# │                                                                                                                 │
# │  I hope this message finds you well. I wanted to provide you with an update regarding the project demo.         │
# │                                                                                                                 │
# │  The demo is nearing completion, though there are still some outstanding items that require additional work.    │
# │  However, I believe we can proceed with showcasing the current progress and communicate that the remaining      │
# │  components are still in progress (WIP).                                                                        │
# │                                                                                                                 │
# │  Please let me know your thoughts on this approach or if you'd prefer to wait until everything is finalized.    │
# │  Your feedback is greatly appreciated.                                                                          │
# │                                                                                                                 │
# │  Thank you for your time and cooperation.                                                                       │
# │                                                                                                                 │
# │  Best regards,                                                                                                  │
# │  [Your Full Name]                                                                                               │
# │  [Your Position]                                                                                                │
# │  [Your Contact Information]                                                                                     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │  This version adheres to professional standards with clear language, proper formatting, and a courteous tone.   │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
